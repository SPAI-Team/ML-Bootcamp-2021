# %% [markdown]
# # SPAI Notebook Introduction
# This notebook demonstrate the anatomy of Jupyter Notebook:
# - Code Cell
# - Code Output Cell
# - Text Cell
#
# Watch the full [Introduction Video](https://youtu.be/Ktu2kEtyytY) here.

# %%
# Importing Commonly Used Libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
 1 + 1

# %%
plt.plot([0,1],[0,1])
plt.show()
